# %%
pip install matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
#df is your dataframe
#example function is applicable for all INT dataframe

# %%
import seaborn as pd

# %%
import pandas as pd

# %%
import pandas as pd
data1 = {
    'StudentID': [101, 102, 103, 105],
    'Name': ['Alice', 'Bob', 'Charlie',"David"],
    'Marks': [85, 90, 88,92]
}

# %%
df1=pd.DataFrame(data1)
df1
# Out:
#    StudentID     Name  Marks
# 0        101    Alice     85
# 1        102      Bob     90
# 2        103  Charlie     88
# 3        105    David     92

# %%
data2 = {  'StudentID': [101, 102, 103, 105],
    'Age': [20,21,22,19],
    'Grade': ["A","B","A","C"]
}
df2=pd.DataFrame(data2)
df2
# Out:
#    StudentID  Age Grade
# 0        101   20     A
# 1        102   21     B
# 2        103   22     A
# 3        105   19     C

# %%
df3=pd.merge(df1,df2, on='StudentID', how='outer') #merge
df3
# Out:
#    StudentID     Name  Marks  Age Grade
# 0        101    Alice     85   20     A
# 1        102      Bob     90   21     B
# 2        103  Charlie     88   22     A
# 3        105    David     92   19     C

# %%
df3 = pd.merge(df1, df2, on="StudentID", how="inner")  # inner join
print(df3)
# Out:
#    StudentID     Name  Marks  Age Grade
# 0        101    Alice     85   20     A
# 1        102      Bob     90   21     B
# 2        103  Charlie     88   22     A
# 3        105    David     92   19     C

# %%
#rightjoin
df3= pd.merge(df1,df2, on="StudentID", how="right")
df3
# Out:
#    StudentID     Name  Marks  Age Grade
# 0        101    Alice     85   20     A
# 1        102      Bob     90   21     B
# 2        103  Charlie     88   22     A
# 3        105    David     92   19     C

# %%
#left join
df3 = pd.merge(df1, df2, on="StudentID", how="left")  # Use 'left', 'right', or 'outer' as needed
df3
# Out:
#    StudentID     Name  Marks  Age Grade
# 0        101    Alice     85   20     A
# 1        102      Bob     90   21     B
# 2        103  Charlie     88   22     A
# 3        105    David     92   19     C

# %%
df3= df3.set_index(["Name"])    #d=c.set_index('StudentID')
df3
# Out:
#          Marks  Age Grade
# Name
# Alice       85   20     A
# Bob         90   21     B
# Charlie     88   22     A
# David       92   19     C

# %%
df3 = df3.reset_index(["Name"])
df
# Out:
#    StudentID   Age Grade  Marks
# 0        101  20.0     A   85.0
# 1        102  21.0     B   78.0
# 2        103  22.0     A    NaN
# 3        104   NaN   NaN   90.0
# 4        105  19.0     C   65.0

# %%
Main_data = pd.read_csv("C:/Users/lakha/Documents/web/diabetescvc.csv")
Main_data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df3.to_csv("C:/Users/lakha/Downloads/ASSISGNMENT.csv",index=False)

# %%
#part3
df=pd.read_csv(r"ASSISGNMENT.csv")
# Out:
#       Name  Marks  Age Grade
# 0    Alice     85   20     A
# 1      Bob     90   21     B
# 2  Charlie     88   22     A
# 3    David     92   19     C

# %%
df=pd.read_csv(r"C:/Users/lakha/Documents/web/diabetescvc.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
print(df.shape)
# Out:
# (768, 9)

# %%
df.fillna(value="100")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df
df["Glucose"] = df["Glucose"].replace(0, df["Glucose"].median())
df["BMI"] = df["BMI"].replace(0, df["BMI"].median())

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...
